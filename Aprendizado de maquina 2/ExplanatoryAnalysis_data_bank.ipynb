# %%
import numpy as np
import pandas as pd
#import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
bank_data = pd.read_csv("/content/drive/MyDrive/Ciencia de Dados/Aprendizado de maquina/bank-data.csv")
bank_data.head(15)
# Out:
#          id  age     sex      region  ...  save_act current_act  mortgage  pep
# 0   ID12101   48  FEMALE  INNER_CITY  ...        NO          NO        NO  YES
# 1   ID12102   40    MALE        TOWN  ...        NO         YES       YES   NO
# 2   ID12103   51  FEMALE  INNER_CITY  ...       YES         YES        NO   NO
# 3   ID12104   23  FEMALE        TOWN  ...        NO         YES        NO   NO
# 4   ID12105   57  FEMALE       RURAL  ...       YES          NO        NO   NO
# 5   ID12106   57  FEMALE        TOWN  ...       YES         YES        NO  YES
# 6   ID12107   22    MALE       RURAL  ...        NO         YES        NO  YES
# 7   ID12108   58    MALE        TOWN  ...       YES         YES        NO   NO
# 8   ID12109   37  FEMALE    SUBURBAN  ...        NO          NO        NO   NO
# 9   ID12110   54    MALE        TOWN  ...       YES         YES        NO   NO
# 10  ID12111   66  FEMALE        TOWN  ...       YES         YES        NO   NO
# ...

# %%
bank_data['income'].mean()
# Out:
# 27524.0312166667

# %%
bank_data.std()
# Out:
# age            14.424947
# income      12899.468246
# children        1.056752
# dtype: float64

# %%
bank_data.max()
# Out:
# id             ID12700
# age                 67
# sex               MALE
# region            TOWN
# income         63130.1
# married            YES
# children             3
# car                YES
# save_act           YES
# current_act        YES
# mortgage           YES
# pep                YES
# dtype: object

# %%
bank_data.min()
# Out:
# id                ID12101
# age                    18
# sex                FEMALE
# region         INNER_CITY
# income            5014.21
# married                NO
# children                0
# car                    NO
# save_act               NO
# current_act            NO
# mortgage               NO
# pep                    NO
# dtype: object

# %%
bank_data.median()
# Out:
# age            42.0
# income      24925.3
# children        1.0
# dtype: float64

# %%
bank_data.quantile([0.25,0.75,0.80,0.85,0.9,0.95])
# Out:
#         age     income  children
# 0.25  30.00  17264.500       0.0
# 0.75  55.25  36172.675       2.0
# 0.80  58.00  38448.020       2.0
# 0.85  60.15  42408.335       2.0
# 0.90  63.00  47253.760       3.0
# 0.95  65.00  52662.905       3.0

# %%
#Chamar atenção para os dados faltantes
bank_data.describe()
# Out:
#               age        income    children
# count  600.000000    600.000000  600.000000
# mean    42.395000  27524.031217    1.011667
# std     14.424947  12899.468246    1.056752
# min     18.000000   5014.210000    0.000000
# 25%     30.000000  17264.500000    0.000000
# 50%     42.000000  24925.300000    1.000000
# 75%     55.250000  36172.675000    2.000000
# max     67.000000  63130.100000    3.000000

# %%
bank_data.corr()
# Out:
#                age    income  children
# age       1.000000  0.752726  0.023572
# income    0.752726  1.000000  0.036761
# children  0.023572  0.036761  1.000000

# %%
newdf = pd.DataFrame(bank_data,columns = ['income','age'])

# %%
newdf.corr()
# Out:
#           income       age
# income  1.000000  0.752726
# age     0.752726  1.000000

# %%
plt.figure(figsize=(6,6))
ax_bar = sns.barplot(data = bank_data, x = 'region', y='income')

# %%
#very easy and cleary explanation about how to create an histogram:
#https://gestaodesegurancaprivada.com.br/histograma-de-frequencia-conceito/
bank_data['income'].hist(bins=50)
plt.xlabel("Income", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
#plt.xlim([0,1000])
# Out:
# Text(0, 0.5, 'Frequency')

# %%
bank_data['age'].hist(bins=50)
plt.xlabel("Age", fontsize=12)
plt.ylabel("Frequency", fontsize=12)
# Out:
# Text(0, 0.5, 'Frequency')

# %%
bank_data.boxplot(column='income',showfliers=True)

# %%
bank_data.boxplot(column='income',by='pep',showfliers=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
plt.figure(figsize = (6,6))
ax = sns.boxplot(data = bank_data, x = 'pep', y='income', width = 0.8, showfliers = True)

# %%
plt.figure(figsize = (6,6))
ax_violin = sns.violinplot(data = bank_data, x = 'pep', y='income', width = 0.8, showfliers = True)

# %%
from pandas.plotting import scatter_matrix

# %%
# criando um dicionario para mapear cada classe para uma cor
classe_cor = {'YES' : 'red','NO' : 'blue'}
# criando uma lista com as cores de cada exemplo
cores = [classe_cor[nome] for nome in bank_data.pep]

# %%
# gerando matriz de scatter plots
scatter_matrix(bank_data, color=cores)
plt.show()
